# %%
# !pip install gspread

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import gspread

# %%
gc = gspread.service_account(filename=("C:\\Users\\Shorif\\Downloads\\dsmlassignment3-fb3f0e322c10.json"))

# %%
gc

# %%
sheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1nyHtotW4SV0TS60BJ4ob0aVDqnqL11U-wgg2PUxGbc0/edit?usp=sharing')

# %%
sheet
# Out:
# <Spreadsheet 'Screen Time Data' id:1nyHtotW4SV0TS60BJ4ob0aVDqnqL11U-wgg2PUxGbc0>

# %%
ws = sheet.worksheet('Screen Time Data')

# %%
ws
# Out:
# <Worksheet 'Screen Time Data' id:516496468>

# %%
df = pd.DataFrame(ws.get_all_records())

# %%
df
# Out:
#     Creativity      Date  Entertainment  Health and Fitness  Other  \
# 0            0  04/17/19              0                   0     41
# 1            0  04/18/19              0                   0      8
# 2            0  04/19/19              3                   0      8
# 3            0  04/20/19              3                   0     38
# 4            1  04/21/19              1                   0     43
# 5            0  04/22/19              0                   4      9
# 6            0  04/23/19              0                  15     41
# 7            0  04/24/19              0                   0     33
# 8            0  04/25/19              0                   0      3
# 9            0  04/26/19             32                   0     29
# 10           0  04/27/19              0                   0     20
# 11           0  04/28/19              0                   0      4
# 12           0  04/29/19              1                  15     13
# ...
